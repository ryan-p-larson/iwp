# %% [markdown]
# # Map Creation
#
# Merging the MOOC Metrics (`mooc-metrics.csv`) with a map. Merging on country ISO code, as provided by Google Analytics.

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ### Countries
#
# Read in the countries and slim down to just the population (for adjusted rates), name, and ISO A2.

# %%
ne_50m = '../data/maps/ne_50m_admin_0_countries.geojson'
countries = gpd.read_file(ne_50m)

# %%
countries.columns
# Out:
# Index(['abbrev', 'abbrev_len', 'adm0_a3', 'adm0_a3_is', 'adm0_a3_un',
#        'adm0_a3_us', 'adm0_a3_wb', 'adm0_dif', 'admin', 'brk_a3', 'brk_diff',
#        'brk_group', 'brk_name', 'continent', 'economy', 'featurecla',
#        'fips_10', 'formal_en', 'formal_fr', 'gdp_md_est', 'gdp_year',
#        'geometry', 'geou_dif', 'geounit', 'gu_a3', 'homepart', 'income_grp',
#        'iso_a2', 'iso_a3', 'iso_n3', 'labelrank', 'lastcensus', 'level',
#        'long_len', 'mapcolor13', 'mapcolor7', 'mapcolor8', 'mapcolor9', 'name',
#        'name_alt', 'name_len', 'name_long', 'name_sort', 'note_adm0',
#        'note_brk', 'pop_est', 'pop_year', 'postal', 'region_un', 'region_wb',
#        'scalerank', 'sov_a3', 'sovereignt', 'su_a3', 'su_dif', 'subregion',
#        'subunit', 'tiny', 'type', 'un_a3', 'wb_a2', 'wb_a3', 'wikipedia',
#        'woe_id'],
#       dtype='object')

# %%
country_df = countries[['iso_a2', 'name_sort', 'scalerank', 'pop_est', 'geometry']]
country_df.head()
# Out:
#   iso_a2    name_sort  scalerank     pop_est  \
# 0     AW        Aruba          3    103065.0
# 1     AF  Afghanistan          1  28400000.0
# 2     AO       Angola          1  12799293.0
# 3     AI     Anguilla          1     14436.0
# 4     AL      Albania          1   3639453.0
#
#                                             geometry
# 0  POLYGON ((-69.89912109375 12.45200195312499, -...
# 1  POLYGON ((74.89130859375001 37.231640625, 74.8...
# 2  (POLYGON ((14.19082031250008 -5.8759765625, 14...
# 3  POLYGON ((-63.001220703125 18.22177734374999, ...
# 4  POLYGON ((20.06396484375 42.547265625, 20.1035...

# %% [markdown]
# ### MOOC Metrics

# %%
metrics_f = '../data/canonical/mooc-metrics.csv'
metrics_df = pd.read_csv(metrics_f)

print ("{} rows".format(len(metrics_df)))
metrics_df.head()
# Out:
# 1071 rows
#    year country                         page  new_users  uniq_pg_views  \
# 0  2017      BD        poetry-and-plays-2017       6975           8331
# 1  2017      IN        poetry-and-plays-2017       3819           8556
# 2  2017      NP        poetry-and-plays-2017       1866           2517
# 3  2017      PK        poetry-and-plays-2017       1372           2171
# 4  2017      IN  fiction-and-nonfiction-2017       1711          12900
#
#    pg_views
# 0     10151
# 1     12849
# 2      3236
# 3      2916
# 4     20355

# %%
# sanity check to make sure we can merge
list_of_map_countries = country_df['iso_a2'].tolist()
test_country = lambda x: x in list_of_map_countries

for country in metrics_df['country'].unique().tolist():
    if (test_country(country) == False):
        print (country)
# Out:
# XK
# ZZ
# nan
# GF
# RE
# BQ
# YT
# MQ

# %% [markdown]
# | ISO A-2 | Country |
# |---|---|
# | `XK` | Temporary for Kosovo |
# | `ZZ` | Unknown |
# | `nan` | Not available, pandas error |
# | `GF` | [French Guiana](https://en.wikipedia.org/wiki/French_Guiana) |
# | `RE` | [Reunion](https://en.wikipedia.org/wiki/R%C3%A9union)
# | `BQ` | [Bonaire, Sint Eustatius and Saba](https://en.wikipedia.org/wiki/Caribbean_Netherlands) |
# | `YT` | [Mayotte](https://en.wikipedia.org/wiki/Mayotte) |
# | `MT` | [Martinique](https://en.wikipedia.org/wiki/Martinique) |
#
#
# From [Wikipedia article on ISO 3166 A-2](https://en.wikipedia.org/wiki/ISO_3166-1_alpha-2)...
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d2/Kingdom_of_the_Netherlands_location_tree.svg"></img>

# %%
country_df[country_df.name_sort == 'Kosovo']['iso_a2']
# Out:
# 119    -99
# Name: iso_a2, dtype: object

# %%
bad_isos = ['nan', 'ZZ', 'GF', 'RE', 'BQ', 'YT', 'MQ']

mask_bad_iso = lambda x: (metrics_df['country'].isin(bad_isos))

metrics_df[mask_bad_iso]
# Out:
#       year country                            page  new_users  uniq_pg_views  \
# 162   2016      ZZ  how-writers-write-fiction-2016         64             87
# 227   2017      ZZ     fiction-and-nonfiction-2017         48            112
# 261   2017      ZZ           poetry-and-plays-2017         31             49
# 438   2016      ZZ                    whitman-2016         18             44
# 469   2015      ZZ  how-writers-write-fiction-2015         35            239
# 545   2016      ZZ  how-writers-write-fiction-2015          7              9
# 584   2017      GF           poetry-and-plays-2017          6              6
# 745   2017      RE           poetry-and-plays-2017          4              5
# 788   2016      BQ  how-writers-write-fiction-2015          2              5
# 904   2017      YT           poetry-and-plays-2017          2              2
# 905   2017      ZZ  how-writers-write-fiction-2015          2              2
# 938   2015      RE  how-writers-write-fiction-2015          1              6
# 1037  2016      MQ  how-writers-write-fiction-2015          1              1
# 1064  2016      RE                    whitman-2016          1              1
#
#       pg_views
# 162        118
# 227        210
# 261         63
# 438         56
# 469        315
# 545         10
# 584          6
# 745          5
# 788          5
# 904          2
# 905          2
# 938          7
# 1037         1
# 1064         1

# %%
# reassign the ISO_A2 for kosovo

#mask_koso = (metrics_df['country'] == 'XK')
#metrics_df.loc[mask_koso, 'country'] = -99

# Change source to change it easier
mask_koso_src = (country_df['name_sort'] == 'Kosovo')
country_df.loc[mask_koso_src, 'iso_a2'] = 'XK'
# Out:
# C:\Users\rlrson\AppData\Local\conda\conda\envs\gviz\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Drop the rows from the dataframe which are unidentifiable
mask_zz = (metrics_df['country'] == 'ZZ')

metrics_df = metrics_df.loc[~mask_zz]

# %%
# keep only the identified countries
mask_good_iso = lambda x: (~metrics_df['country'].isin(bad_isos))

export_df = metrics_df[mask_good_iso]

print ("{} rows".format(len(export_df)))
# Out:
# 1057 rows

# %% [markdown]
# ### Merging

# %%
# get rid of antartica
country_df = country_df[country_df.iso_a2 != 'AQ']

# rename the columns
country_df.columns = ['iso', 'country', 'scalerank', 'population', 'geometry']

# drop the scale rank column
country_df.drop('scalerank', axis=1, inplace=True)

# %%
country_df
# Out:
#      iso                              country   population  \
# 0     AW                                Aruba     103065.0
# 1     AF                          Afghanistan   28400000.0
# 2     AO                               Angola   12799293.0
# 3     AI                             Anguilla      14436.0
# 15   (POLYGON ((158.8788085937501 -54.709765625, 15...
# 16   POLYGON ((16.953125 48.598828125, 16.948828125...
# 17   (POLYGON ((45.15283203125003 39.58266601562502...
# 18   POLYGON ((30.55361328125002 -2.400097656250011...
# 19   POLYGON ((4.816015625000034 51.43281249999995,...
# 20   POLYGON ((3.595410156250011 11.6962890625, 3.5...
# 21   POLYGON ((0.217480468750011 14.91147460937499,...
# 22   (POLYGON ((91.94921875000003 21.50805664062503...
# 23   POLYGON ((28.58535156250002 43.742236328125, 2...
# 24   POLYGON ((50.60722656250002 25.88310546875, 50...
# 25   (POLYGON ((-73.02685546874994 21.1923828125000...
# 26   POLYGON ((16.91865234374998 45.27656249999998,...
# 27   POLYGON ((-62.83193359374999 17.87646484375, -...
# 28   POLYGON ((28.14794921875 56.142919921875, 28.2...
# 29   (POLYGON ((-87.85292968749999 17.4228515625, -...
# 30   POLYGON ((-64.73027343749999 32.29345703125, -...
# ..                                                 ...
# 211  POLYGON ((23.98027343750002 19.496630859375, 2...
# 212  POLYGON ((0.900488281250006 10.99326171874999,...
# 213  (POLYGON ((99.66308593749997 6.521923828124983...
# 214  (POLYGON ((70.70166015625003 39.82529296874998...
# 215  (POLYGON ((53.10957031250004 38.80307617187501...
# 216  (POLYGON ((124.3193359375 -9.413769531249983, ...
# 217  (POLYGON ((-174.913134765625 -21.3004882812500...
# 218  (POLYGON ((-61.01210937499997 10.1343261718749...
# 219  (POLYGON ((10.95761718750006 33.72207031250005...
# 220  (POLYGON ((25.97001953125005 40.136328125, 25....
# 221  (POLYGON ((118.4074218750001 24.52211914062499...
# 222  (POLYGON ((39.711328125 -7.977441406250023, 39...
# 223  POLYGON ((33.90322265625002 -1.002050781250006...
# 224  (POLYGON ((32.01220703124997 46.20390624999999...
# 225  POLYGON ((-53.37060546875 -33.7421875, -53.419...
# 226  (POLYGON ((-155.58134765625 19.01201171875002,...
# 227  (POLYGON ((71.77968749999999 39.95024414062505...
# 228  POLYGON ((12.43916015625001 41.898388671875, 1...
# 229  (POLYGON ((-61.33437 12.69521484374999, -61.34...
# 230  (POLYGON ((-60.99790039062498 8.86733398437496...
# 231  (POLYGON ((-64.59365234374997 18.4028320312499...
# 232  (POLYGON ((-64.765625 17.79433593749999, -64.6...
# 233  (POLYGON ((106.6174804687501 8.68281250000004,...
# 234  (POLYGON ((169.8962890625001 -20.1866210937500...
# 235  (POLYGON ((-178.0466796875 -14.31835937499999,...
# 236  (POLYGON ((-171.4541015625 -14.04648437500002,...
# 237  (POLYGON ((53.76318359374997 12.63681640624999...
# 238  (POLYGON ((37.85693359375003 -46.9442382812499...
# 239  POLYGON ((32.919921875 -9.407421875000011, 32....
# 240  POLYGON ((31.28789062500002 -22.40205078125001...
#
# [240 rows x 4 columns]

# %%
# rename before merge
export_df.rename(columns={'country': 'iso'}, inplace=True)
# Out:
# C:\Users\rlrson\AppData\Local\conda\conda\envs\gviz\lib\site-packages\pandas\core\frame.py:2844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)

# %%
rate_df = export_df.merge(country_df.drop('geometry', axis=1), on='iso')
rate_df.head(10)
# Out:
#    year iso                            page  new_users  uniq_pg_views  \
# 0  2017  BD           poetry-and-plays-2017       6975           8331
# 1  2017  BD     fiction-and-nonfiction-2017        108            283
# 2  2016  BD  how-writers-write-fiction-2016         52             80
# 3  2016  BD                flash-write-2016         32            140
# 4  2015  BD  how-writers-write-fiction-2015         29            165
# 5  2016  BD  how-writers-write-fiction-2015         10             15
# 6  2016  BD                    whitman-2016         10             12
# 7  2017  BD  how-writers-write-fiction-2016          2              2
# 8  2017  IN           poetry-and-plays-2017       3819           8556
# 9  2017  IN     fiction-and-nonfiction-2017       1711          12900
#
#    pg_views     country    population
# 0     10151  Bangladesh  1.560509e+08
# 1       496  Bangladesh  1.560509e+08
# 2       115  Bangladesh  1.560509e+08
# 3       208  Bangladesh  1.560509e+08
# 4       232  Bangladesh  1.560509e+08
# 5        16  Bangladesh  1.560509e+08
# 6        12  Bangladesh  1.560509e+08
# 7         2  Bangladesh  1.560509e+08
# 8     12849       India  1.166079e+09
# 9     20355       India  1.166079e+09

# %%
# Calculate population adjusted rates
rate_df['new_users_rate'] = rate_df['new_users'] / rate_df['population']
rate_df['uniq_pg_views_rate'] = rate_df['uniq_pg_views'] / rate_df['population']
rate_df['pg_views_rate'] = rate_df['pg_views'] / rate_df['population']

# %%
#rate_df.to_csv('../data/canonical/mooc-metrics-population.csv', index=False)

# %%
#country_df.to_file('../data/maps/countries-pop.geojson', driver='GeoJSON')

# %% [markdown]
# ### Single File
#
# Add the classes as a list into the raw GeoJSON.

# %%
import json
country_json_str = country_df.to_json()

# %%
country_json = json.loads(country_json_str)
country_json.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
country_json['features'][0]
# Out:
# {'geometry': {'coordinates': [[[-69.89912109375, 12.452001953124991],
#     [-69.895703125, 12.422998046874994],
#     [-69.94218749999999, 12.438525390624989],
#     [-70.004150390625, 12.50048828125],
#     [-70.06611328125, 12.546972656249991],
#     [-70.05087890624999, 12.597070312499994],
#     [-70.035107421875, 12.614111328124991],
#     [-69.97314453125, 12.567626953125],
#     [-69.91181640625, 12.48046875],
#     [-69.89912109375, 12.452001953124991]]],
#   'type': 'Polygon'},
#  'id': '0',
#  'properties': {'country': 'Aruba', 'iso': 'AW', 'population': 103065.0},
#  'type': 'Feature'}

# %%
# each feature is saved in a features list.
# we can use a simple list comprehension if we can use the ISO as a lookup key

# create the lookup for said key

# %%
rate_df.drop(['country', 'population', 'new_users_rate','uniq_pg_views_rate','pg_views_rate'], 
             axis=1, inplace=True)

# %%
list_of_classes = rate_df.to_dict('records')

iso_lookup = {}

for record in list_of_classes:
    iso = record['iso']
    if (iso in iso_lookup):
        iso_lookup[iso].append(record)
    else:
        iso_lookup[iso] = []
        iso_lookup[iso].append(record)

# %%
for country in country_json['features']:
    iso = country['properties']['iso']
    
    if (iso in iso_lookup):
        #print (iso, len(iso_lookup[iso]))
        country['properties']['classes'] = iso_lookup[iso]
    else:
        country['properties']['classes'] = []

# %%
# calculate the overall for each country
for country in country_json['features']:
    props = country['properties']
    
    for attr in ['new_users', 'uniq_pg_views', 'pg_views']:
        key = 'tot_' + attr
        props[key] = sum(map(lambda x: x[attr], props['classes']))

# %%
with open('../data/canonical/country-classes.geojson', 'w') as outfile:
    json.dump(country_json, outfile)
