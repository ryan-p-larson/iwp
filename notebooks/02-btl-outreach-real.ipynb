# %% [markdown]
# # Outreach Data
#
# This notebook is just looking at the raw data, downloading it and getting it in the right shape.
#
# #### Requirements
#
# *Note-to-self:* Here's a list of things to keep in mind when going through the data/analysis.
#
# - Gaza, Tel Aviv, Israel, and Palestine need segmentation. (To be done by Natasa)
# - Some projects/classifications will need links added.

# %%
# Project variables
data_dir = '../data/'

outreach_f = data_dir + '/original/IWP_map.csv'

# %%
# Libraries
import pandas as pd
import json

# %matplotlib inline

# %% [markdown]
# #### Extract Outreach data from CSV

# %%
df = pd.read_csv(outreach_f)

print ("{} rows".format(len(outreach_f)))
print (df.columns.tolist())
df.head(20)
# Out:
# 29 rows
# ['Category', 'Country', 'Year', 'link']
#                     Category                  Country  Year  \
# 0   International Conference                   Greece  2006
# 1               Reading tour           Syria - Aleppo  2007
# 2               Reading tour         Syria - Damascus  2007
# 3               Reading tour                  Jordan   2007
# 4               Reading tour                Jerusalem  2007
# 5               Reading tour  Palestinian Territories  2007
# 6               Reading tour                   Turkey  2007
# 7   International Conference                   Greece  2007
# 8               Reading tour                   Cyprus  2008
# 9               Reading tour                     Oman  2008
# 10              Reading tour    Saudi Arabia - Riyadh  2008
# 11              Reading tour   Saudi Arabia - Dhahran  2008
# 12              Reading tour    Saudi Arabia - Jeddah  2008
# 13              Reading tour                    Yemen  2008
# 14  International Conference                   Greece  2008
# 15              Reading tour                    Kenya  2009
# 16  International Conference            Morocco - Fes  2009
# 17  International Conference                    China  2009
# 18              Reading tour     Morocco - Casablanca  2009
# 19              Reading tour                  Tunisia  2009
#
#                                                  link
# 0   https://iwp.uiowa.edu/programs/international-c...
# 1   https://iwp.uiowa.edu/programs/reading-abroad/...
# 2   https://iwp.uiowa.edu/programs/reading-abroad/...
# 3   https://iwp.uiowa.edu/programs/reading-abroad/...
# 4   https://iwp.uiowa.edu/programs/reading-abroad/...
# 5   https://iwp.uiowa.edu/programs/reading-abroad/...
# 6   https://iwp.uiowa.edu/programs/reading-abroad/...
# 7   https://iwp.uiowa.edu/programs/international-c...
# 8   http://iwp.uiowa.edu/programs/reading-abroad/2...
# 9   http://iwp.uiowa.edu/programs/reading-abroad/2...
# 10  http://iwp.uiowa.edu/programs/reading-abroad/2...
# 11  http://iwp.uiowa.edu/programs/reading-abroad/2...
# 12  http://iwp.uiowa.edu/programs/reading-abroad/2...
# 13  http://iwp.uiowa.edu/programs/reading-abroad/2...
# 14  https://iwp.uiowa.edu/programs/international-c...
# 15  https://iwp.uiowa.edu/programs/reading-abroad/...
# 16  https://iwp.uiowa.edu/programs/international-c...
# 17  https://iwp.uiowa.edu/programs/life-of-discove...
# 18  https://iwp.uiowa.edu/programs/reading-abroad/...
# 19  https://iwp.uiowa.edu/programs/reading-abroad/...

# %%
df.Country.unique().tolist()
# Out:
# ['Greece',
#  'Syria - Aleppo',
#  'Syria - Damascus',
#  'Jordan ',
#  'Jerusalem',
#  'Palestinian Territories',
#  'Turkey',
#  'Cyprus',
#  'Oman',
#  'Saudi Arabia - Riyadh',
#  'Saudi Arabia - Dhahran',
#  'Saudi Arabia - Jeddah',
#  'Yemen',
#  'Kenya',
#  'Morocco - Fes',
#  'China',
#  'Morocco - Casablanca',
#  'Tunisia',
#  'Morocco - Essaouira',
#  'Nepal',
#  'Pakistan',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Uruguay',
#  'Bolivia',
#  'Congo - Kinshasa',
#  'Congo - Brazzaville',
#  'Brazil - Fortaleza',
#  'Brazil - Sao Paolo',
#  'Brazil - Brasilia',
#  'Cambodia - Phnom Penh',
#  'Cambodia - Kampong Speu',
#  'Cambodia - Krong Kampong Chhnang',
#  'Cambodia - Krong Siem Reap',
#  'Vietnam - Hanoi',
#  'Mozambique',
#  'Zimbabwe - Harare',
#  'Zimbabwe - Masvingo',
#  'Iraq - Basrah',
#  'Iraq - Baghdad',
#  'Iraq - Erbil',
#  'Sudan',
#  'South Sudan',
#  'Uzbekistan',
#  'Turkmenistan',
#  'United Arab Emirates - Abu Dhabi',
#  'United Arab Emirates - Dubai',
#  'United Arab Emirates - Sharjah',
#  'Burma',
#  'Maldives',
#  'Haiti',
#  'Cuba',
#  'Armenia',
#  'Venezuela',
#  'Colombia',
#  'Ukraine',
#  'Bahrain',
#  'South Africa',
#  'India',
#  'Ecuador',
#  'Afghanistan - Jalalabad',
#  'Afghanistan - Kabul',
#  'Afghanistan - Mazar-i-Sharif',
#  'Morocco - Tangiers']

# %% [markdown]
# #### Add Geocoded lat/longs to Dataframe
#
# - City Column
#     * Split from existing columns
#     * Add capital cities to those countries without duplicates
# - Geocode Lat/Longs

# %%
# add city column to dataframe
df['city'] = df['Country'].apply(lambda x: x.split(' - ')[1] if len(x.split(' - '))>1 else '')

# %%
# Clean the country column
df['Country'] = df['Country'].apply(lambda x: x.split(' - ')[0] if len(x.split(' - '))>1 else x.strip())

# %% [markdown]
# Download info from Github to get capitals

# %%
capitals_url = "https://raw.githubusercontent.com/mledoze/countries/master/dist/countries.csv"
country_info = pd.read_csv(capitals_url, sep=';')

print(country_info.columns.tolist())
country_info.head()
# Out:
# ['name', 'tld', 'cca2', 'ccn3', 'cca3', 'cioc', 'currency', 'callingCode', 'capital', 'altSpellings', 'region', 'subregion', 'languages', 'translations', 'latlng', 'demonym', 'landlocked', 'borders', 'area']
#                                                 name  tld cca2   ccn3 cca3  \
# 0                Aruba,Aruba,Aruba,Aruba,Aruba,Aruba  .aw   AW  533.0  ABW
# 1  Afghanistan,Islamic Republic of Afghanistan,جم...  .af   AF    4.0  AFG
# 2  Angola,Republic of Angola,República de Angola,...  .ao   AO   24.0  AGO
# 3                Anguilla,Anguilla,Anguilla,Anguilla  .ai   AI  660.0  AIA
# 4  Åland Islands,Åland Islands,Landskapet Åland,Å...  .ax   AX  248.0  ALA
#
#   cioc currency callingCode     capital  \
# 0  ARU      AWG         297  Oranjestad
# 1  AFG      AFN          93       Kabul
# 2  ANG      AOA         244      Luanda
# 3  NaN      XCD        1264  The Valley
# 4  NaN      EUR         358   Mariehamn
#
#                                   altSpellings    region        subregion  \
# 0                                           AW  Americas        Caribbean
# 1                                AF,Afġānistān      Asia    Southern Asia
# 2  AO,República de Angola,ʁɛpublika de an'ɡɔla    Africa    Middle Africa
# 3                                           AI  Americas        Caribbean
# 4                   AX,Aaland,Aland,Ahvenanmaa    Europe  Northern Europe
#
#              languages                                       translations  \
# 0     Dutch,Papiamento  Aruba,Aruba,Aruba,Aruba,Aruba,Aruba,Aruba,Arub...
# 1  Dari,Pashto,Turkmen  Islamic Republic of Afghanistan,Affganistan,Is...
# 2           Portuguese  Republic of Angola,Angola,Republik Angola,Ango...
# 3              English  Anguilla,Anguilla,Anguilla,Anguilla,Anguilla,A...
# 4              Swedish  Åland-Inseln,Åland,Ahvenanmaa,Ahvenanmaa,Aland...
#
#                latlng     demonym  landlocked                  borders  \
# 0   12.5,-69.96666666      Aruban         NaN                      NaN
# 1               33,65      Afghan         1.0  IRN,PAK,TKM,UZB,TJK,CHN
# 2          -12.5,18.5     Angolan         NaN          COG,COD,ZMB,NAM
# 3  18.25,-63.16666666  Anguillian         NaN                      NaN
# 4      60.116667,19.9    Ålandish         NaN                      NaN
#
#         area
# 0      180.0
# 1   652230.0
# 2  1246700.0
# 3       91.0
# 4     1580.0

# %%
country_info['name'] = country_info.name.apply(lambda x: x.split(',')[0])

# %%
country_names = country_info['name'].tolist()

for x in df.Country.unique().tolist():
    if (x in country_names) == False:
        print (x)
# Out:
# Jerusalem
# Palestinian Territories
# Congo
# Burma

# %%
# Rename offending countries to merge with capitals

##NOTE: there is only Palestinian tyerritories, no palestine
## the capital of Israel is Jerusalem, so the renaming still holds.

rename_capitals = {
    'Palestinian Territories': 'Palestine',
    'Congo': 'DR Congo',
    'Burma': 'Myanmar',
    'Jerusalem': 'Israel'
}
df['Country'] = df['Country'].apply(lambda x: rename_capitals[x] if x in rename_capitals else x)

# %%
for x in df.Country.unique().tolist():
    if (x in country_names) == False:
        print (x)
#### All clear

# %%
captial_lookup = country_info[['name', 'capital']].set_index('name')

def get_country_captial(country, country_df):
    return country_df.loc[country]['capital']

# %%
# repopulate the empty city cells
df['city'] = df.apply(lambda x: get_country_captial(x['Country'], captial_lookup) if (x['city'] == '') else x['city'], axis=1)

# %% [markdown]
# #### Geocode the Outreach programs

# %%
from geopy.geocoders import GoogleV3
from geopy.exc import GeocoderTimedOut
from time import sleep

google_geocoder = GoogleV3()

def find_map_coordinates(full_address, geolocator):
    """
    Function to find latitude and longtitude for the address.
    Input
    :full_address: input string with full address (like "55 rue du Faubourg Saint-Honore, 75008, Paris")
    :geolocator: geocoder object from geopy module
    
    Output
    :latitude, longitude: values of latitude and longtitude for the input address
    """
    timeout_secs = 15
    try:
        location = geolocator.geocode(full_address, timeout=timeout_secs)
        sleep(5)
        return location.latitude, location.longitude
    except GeocoderTimedOut:
        sleep(timeout_secs)
        return 0, 0

# %%
df['fulladdress'] = df['city'] + ', ' + df['Country']

# %%
# Find coordinates by appling helper function. We pass also geolocator object
locs = df['fulladdress'].apply(find_map_coordinates, args=(google_geocoder,)).tolist()

# Add new columns to the dataframe with latitude and longtitude values
df['lat'], df['lng'] = zip(*locs)

# %%
df
# Out:
#                     Category               Country  Year  \
# 0   International Conference                Greece  2006
# 1               Reading tour                 Syria  2007
# 2               Reading tour                 Syria  2007
# 3               Reading tour                Jordan  2007
# 4               Reading tour                Israel  2007
# 5               Reading tour             Palestine  2007
# 6               Reading tour                Turkey  2007
# 7   International Conference                Greece  2007
# 8               Reading tour                Cyprus  2008
# 9               Reading tour                  Oman  2008
# 10              Reading tour          Saudi Arabia  2008
# 11              Reading tour          Saudi Arabia  2008
# 12              Reading tour          Saudi Arabia  2008
# 13              Reading tour                 Yemen  2008
# 14  International Conference                Greece  2008
# 15              Reading tour                 Kenya  2009
# 16  International Conference               Morocco  2009
# 17  International Conference                 China  2009
# 18              Reading tour               Morocco  2009
# 19              Reading tour               Tunisia  2009
# 20  International Conference               Morocco  2010
# 21  International Conference                 China  2010
# 22  International Conference                 China  2011
# 23              Reading tour                 Nepal  2011
# 24              Reading tour              Pakistan  2011
# 25              Reading tour  United Arab Emirates  2011
# 26              Reading tour           Afghanistan  2011
# 27              Reading tour               Uruguay  2011
# 28              Reading tour               Bolivia  2011
# 29              Reading tour                 Kenya  2011
# ..                       ...                   ...   ...
# 46              Reading tour                  Iraq  2013
# 47              Reading tour                  Iraq  2013
# 48              Reading tour                 Sudan  2013
# 49              Reading tour           South Sudan  2013
# 50              Reading tour            Uzbekistan  2013
# 51              Reading tour          Turkmenistan  2013
# 52              Reading tour  United Arab Emirates  2013
# 53              Reading tour  United Arab Emirates  2013
# 54              Reading tour  United Arab Emirates  2013
# 55              Reading tour               Myanmar  2013
# 56               Silk Routes              Maldives  2014
# 57              Reading tour                 Haiti  2014
# 58              Reading tour                  Cuba  2014
# 59              Reading tour                 China  2014
# 60              Reading tour  United Arab Emirates  2014
# 61              Reading tour                Turkey  2014
# 62              Reading tour               Armenia  2014
# 63              Reading tour             Venezuela  2015
# 64              Reading tour              Colombia  2015
# 65              Reading tour               Ukraine  2015
# 66         Distance Learning                Jordan  2015
# 67         Distance Learning               Bahrain  2015
# 68              Reading tour                Jordan  2016
# 69              Reading tour          South Africa  2016
# 70              Reading tour                 India  2016
# 71              Reading tour               Ecuador  2016
# 72         Distance Learning           Afghanistan  2016
# 73         Distance Learning           Afghanistan  2016
# 74         Distance Learning           Afghanistan  2016
# 75              Reading tour               Morocco  2017
#
#                                                  link            city  \
# 0   https://iwp.uiowa.edu/programs/international-c...          Athens
# 1   https://iwp.uiowa.edu/programs/reading-abroad/...          Aleppo
# 2   https://iwp.uiowa.edu/programs/reading-abroad/...        Damascus
# 3   https://iwp.uiowa.edu/programs/reading-abroad/...           Amman
# 4   https://iwp.uiowa.edu/programs/reading-abroad/...       Jerusalem
# 5   https://iwp.uiowa.edu/programs/reading-abroad/...        Ramallah
# 58                     Havana, Cuba  23.113592  -82.366596
# 59                   Beijing, China  39.904200  116.407396
# 60  Abu Dhabi, United Arab Emirates  24.453884   54.377344
# 61                   Ankara, Turkey  39.933363   32.859742
# 62                 Yerevan, Armenia  40.179186   44.499103
# 63               Caracas, Venezuela  10.480594  -66.903606
# 64                 Bogotá, Colombia   4.710989  -74.072092
# 65                    Kiev, Ukraine  50.450100   30.523400
# 66                    Amman, Jordan  31.945367   35.928372
# 67                  Manama, Bahrain  26.228516   50.586050
# 68                    Amman, Jordan  31.945367   35.928372
# 69           Pretoria, South Africa -25.747868   28.229271
# 70                 New Delhi, India  28.613939   77.209021
# 71                   Quito, Ecuador  -0.180653  -78.467838
# 72           Jalalabad, Afghanistan  34.419849   70.472943
# 73               Kabul, Afghanistan  34.555349   69.207486
# 74      Mazar-i-Sharif, Afghanistan  36.692617   67.117951
# 75                Tangiers, Morocco  35.759465   -5.833954
#
# [76 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Category', 'Country', 'Year', 'link', 'city', 'fulladdress', 'lat',
#        'lng'],
#       dtype='object')

# %% [markdown]
# #### Rename Columns
#
# Something human readable, prefferably.

# %%
new_cols = ['category', 'country', 'year', 'link', 'city', 'full', 'lat', 'lng']
df.columns = new_cols

df.head(2)
# Out:
#                    category country  year  \
# 0  International Conference  Greece  2006
# 1              Reading tour   Syria  2007
#
#                                                 link    city            full  \
# 0  https://iwp.uiowa.edu/programs/international-c...  Athens  Athens, Greece
# 1  https://iwp.uiowa.edu/programs/reading-abroad/...  Aleppo   Aleppo, Syria
#
#          lat        lng
# 0  37.983810  23.727539
# 1  36.202105  37.134260

# %%
# drop the full address column
df = df[['category', 'country', 'year', 'link', 'city', 'lat', 'lng']]

# %% [markdown]
# ---

# %%
outreach_canon_f = '../data/canonical/outreach-programs.csv'
df.to_csv(outreach_canon_f, index=False)

# %% [markdown]
# #### **OLD**: *Rename Countries to match participant naming.*

# %%
# name_sort aliases
name_sort = {
    'Russia': 'Russian Federation',
    #
    'USA': 'United States of America',
    'U.S.': 'United States of America',
    'US': 'United States of America',
    #
    'Burma': 'Myanmar',
    #
    'Kyrgyzstan': 'Kyrgyz Republic',
    #
    'Kuwait (but she is Lebanese)': 'Kuwait',
    #
    'Syria': 'Syrian Arab Republic',
    'Syria (Palestinian Syrian)': 'Syrian Arab Republic',
    #
    'Egypt': 'Egypt, Arab Rep.',
    #
    'Palestine': 'Palestine (West Bank and Gaza)',
    'West Bank': 'Palestine (West Bank and Gaza)',
    'Gaza': 'Palestine (West Bank and Gaza)',
    'Palestinian Territories': 'Palestine (West Bank and Gaza)',
    'Palestinian Territories (Gaza)': 'Palestine (West Bank and Gaza)',
    'Palestinian Territories (West Bank)': 'Palestine (West Bank and Gaza)',
    #
    'Venezuela': 'Venezuela, RB',
    #
    'Yemen': 'Yemen, Rep.'
    
}

# strip trailing spaces before dict lookup
df['Country'] = df['Country'].str.strip()

# dict lookup
df['Country'] = df['Country'].map(lambda x: name_sort[x] if x in name_sort else x)
