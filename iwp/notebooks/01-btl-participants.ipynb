# %% [markdown]
# # 01-Data Preparation
#
# This notebook is just looking at the raw data, downloading it and getting it in the right shape.
#
# #### Requirements
#
# *Note-to-self:* Here's a list of things to keep in mind when going through the data/analysis.
#
# - Yekaterinburg, RU needs GPS coordinates adjusted to `(56.8, 60.6)`.
# - `15-Jul` -> yr. 2015
#
# - Some projects/classifications will need links added.

# %%
# Project variables
data_dir = '../data/'

btl_f = data_dir + 'BTL-data.json'

# %%
# Libraries
import pandas as pd
import json

# %matplotlib inline

# %%
# Read in the ArcGIS data
with open(btl_f) as data_file:    
    data = json.load(data_file)

# %%
data.keys()
# Out:
# dict_keys(['layers', 'showLegend', 'visibility', 'opacity'])

# %%
layers = data['layers'][0]

# %%
print("Layer keys: {}".format(layers.keys()))

layers['featureSet'].keys()
# Out:
# Layer keys: dict_keys(['layerDefinition', 'featureSet', 'nextObjectId', 'popupInfo'])
# dict_keys(['features', 'geometryType'])

# %%
features = layers['featureSet']['features']

print ("{} many features included.".format(len(features)))
# Out:
# 316 many features included.

# %%
features[0]
# Out:
# {'attributes': {'BTL_Year': '8-Jul',
#   'BTL_status': 'Student',
#   'City_of_Residence_during_BTL*': 'Adonis Zouk Mosbeh',
#   'Country_of_Residence_during_BTL': 'Lebanon',
#   'First_Name': 'Eliane',
#   'Last_Name': 'Aoun',
#   'Latitude': 33.955,
#   'Longitude': 35.61472,
#   '__OBJECTID': 0},
#  'geometry': {'spatialReference': {'wkid': 102100},
#   'x': 3964612,
#   'y': 4022761}}

# %%
filt_features = [x['attributes'] for x in features]
df = pd.DataFrame(filt_features)

df.drop('__OBJECTID', axis=1, inplace=True,)
df.head()
# Out:
#   BTL_Year BTL_status City_of_Residence_during_BTL*  \
# 0    8-Jul    Student            Adonis Zouk Mosbeh
# 1    8-Jul    Student                        Kuwait
# 2    8-Jul    Student                     Bazourieh
# 3    8-Jul    Student                  Kufur Yassif
# 4    8-Jul    Student                         Amman
#
#   Country_of_Residence_during_BTL First_Name Last_Name  Latitude  Longitude
# 0                         Lebanon     Eliane      Aoun  33.95500   35.61472
# 1                          Jordan       Hiba  as-Masri  29.36972   47.97833
# 2                         Lebanon        Ali    Awarke  33.25389   35.27167
# 3                          Israel      Randa  Ghantous  32.95472   35.16528
# 4                          Jordan      Karim     Ghawi  31.94972   35.93278

# %% [markdown]
# #### Format the `BTL_Year`

# %%
df.BTL_Year.unique()
# Out:
# array(['8-Jul', '9-Jul', '10-Jul', '11-Jul', '12-Jul', '13-Jul', '14-Jul',
#        '17-Jul', '15-Jul', '16-Jul'], dtype=object)

# %%
# add zeroes so the date can be formatted
df['BTL_Year'] = df['BTL_Year'].str.zfill(6)

df['BTL_Year'] = pd.to_datetime(df.BTL_Year, format='%y-%b')

# change 2008-07-01 -> 2008
df['BTL_Year'] = df['BTL_Year'].map(lambda x: x.year)

df.BTL_Year.head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: BTL_Year, dtype: int64

# %% [markdown]
# #### Rename Columns
#
# Something human readable, prefferably.

# %%
new_cols = ['year', 'status', 'city',
           'country', 'first_name', 'last_name',
           'lat', 'long']
df.columns = new_cols

df.head(2)
# Out:
#    year   status                city  country first_name last_name       lat  \
# 0  2008  Student  Adonis Zouk Mosbeh  Lebanon     Eliane      Aoun  33.95500
# 1  2008  Student              Kuwait   Jordan       Hiba  as-Masri  29.36972
#
#        long
# 0  35.61472
# 1  47.97833

# %% [markdown]
# ---

# %%
print ("Years: {}".format(df.year.unique()))

# Years plot, get cnts
yrs = df.year.value_counts().reset_index()
# rename for ease
yrs.columns = ['year', 'count']
# Sort by natural intuition
yrs.sort_values('year', inplace=True)

# plot it !
yrs.plot(kind='bar', x='year', y='count')
# Out:
# Years: [2008 2009 2010 2011 2012 2013 2014 2017 2015 2016]

# %% [markdown]
# ---

# %%
print ("Statuses: {}".format(df.status.unique()))


statuses = df['status'].value_counts()
statuses
# Out:
# Statuses: ['Student' 'Chaperone' 'Faculty' 'NSPP Mentor']
# Student        264
# Chaperone       28
# Faculty         22
# NSPP Mentor      2
# Name: status, dtype: int64

# %% [markdown]
# #### Format Country Names

# %%
df.country.nunique()
# Out:
# 40

# %%
df.country.value_counts()
# Out:
# Russia                                 57
# USA                                    50
# U.S.                                   25
# US                                     22
# Lebanon                                15
# Jordan                                 14
# Morocco                                13
# Israel                                 12
# Egypt                                  12
# Bahrain                                12
# Armenia                                 7
# Syria                                   7
# Turkey                                  7
# Tunisia                                 7
# Algeria                                 5
# Canada                                  3
# Palestinian Territories                 3
# West Bank                               3
# Palestine                               3
# India                                   3
# Pakistan                                3
# Kyrgyzstan                              3
# Bulgaria                                3
# Saudi Arabia                            3
# Sri Lanka                               3
# Oman                                    2
# Palestinian Territories (Gaza)          2
# Nepal                                   2
# China                                   2
# Gaza                                    2
# Iraq                                    2
# Bangladesh                              1
# Libya                                   1
# Sudan                                   1
# Syria (Palestinian Syrian)              1
# Palestinian Territories (West Bank)     1
# Kuwait (but she is Lebanese)            1
# Yemen                                   1
# France                                  1
# Kuwait                                  1
# Name: country, dtype: int64

# %%
country_aliases = {
    'U.S.': 'USA',
    'US': 'USA',
    'Kuwait (but she is Lebanese)': 'Kuwait'
}

df['country'] = df['country'].map(lambda x: country_aliases[x] if x in country_aliases else x)

# %%
print ("Unique Countries: {}".format(df.country.unique()))

# Years plot, get cnts
country_cnts = df.country.value_counts().reset_index()
# rename for ease
country_cnts.columns = ['country', 'count']

# sort 
country_cnts.sort_values('count', inplace=True)

# plot it !
#country_cnts.plot.barh(yticks=country_cnts.country.tolist())
# Out:
# Unique Countries: ['Lebanon' 'Jordan' 'Israel' 'Palestine' 'Syria' 'West Bank' 'Bahrain'
#  'Saudi Arabia' 'Oman' 'Gaza' 'Libya' 'Algeria' 'Egypt' 'Morocco' 'Tunisia'
#  'Palestinian Territories (Gaza)' 'Bulgaria' 'USA' 'Russia' 'Canada'
#  'Palestinian Territories (West Bank)' 'Palestinian Territories' 'Yemen'
#  'Kuwait' 'Syria (Palestinian Syrian)' 'Sudan' 'France' 'Turkey' 'Iraq'
#  'Armenia' 'China' 'Bangladesh' 'Sri Lanka' 'Pakistan' 'Nepal' 'India'
#  'Kyrgyzstan']

# %%
df.tail(50)
# Out:
#      year     status                         city     country    first_name  \
# 266  2016    Student                 Ekaterinburg      Russia         Yulia
# 267  2016    Student                       Moscow      Russia        Mariia
# 268  2016    Student                  Kaliningrad      Russia     Ekaterina
# 269  2016    Student           Ulan-Ude, Buryatia      Russia    Anastasiia
# 270  2016    Student                       Moscow      Russia       Vitalii
# 271  2016    Student                       Moscow      Russia       Georgii
# 272  2016    Student                       Moscow      Russia         Artem
# 273  2016    Student      Saratov, Saratov Oblast      Russia    Anastasiia
# 274  2016    Student           Salt Lake City, UT         USA         Isaac
# 275  2016    Student                 Bethesda, MD         USA       Camille
# 276  2016    Student                   Irvine, CA         USA        Vishwa
# 277  2016    Student                     Anza, CA         USA         Emily
# 278  2016    Student                  Seattle, WA         USA          Siri
# 279  2016    Student        Greenwood Village, CO         USA         Ellen
# 280  2016    Student                   Tucson, AZ         USA       Caitlin
# 281  2016    Student            Hermosa Beach, CA         USA      Jennifer
# 282  2016    Student                  Kamuela, HI         USA          Kyra
# 283  2016    Student                  Bozeman, MT         USA           Ian
# 284  2016    Student             South Orange, NJ         USA          Lily
# 285  2016    Student                  Chicago, IL         USA         Grace
# 286  2016    Student                        Dhaka  Bangladesh      Mohammed
# 287  2016    Student                      Colombo   Sri Lanka     Imthishal
# 288  2016    Student                      Colombo   Sri Lanka       Fathima
# 289  2016    Student                       Lahore    Pakistan         Ahmad
# 290  2016    Student                       Punjab    Pakistan  Zainab Nasim
# 291  2016    Student                      Karachi    Pakistan         Amsel
# 292  2016    Student                    Kathmandu       Nepal       Jigyasa
# 293  2016    Student                    Kathmandu       Nepal        Chiran
# 294  2016    Student                  East Sikkim       India       Ngawang
# 295  2016    Student                       Mumbai       India     Satyendra
# 296  2016    Student                      Karakol  Kyrgyzstan        Sabina
# 297  2016    Student                      Bishkek  Kyrgyzstan        Azamat
# 298  2016    Student           Salt Lake City, UT         USA        Claire
# 299  2016    Student               Lake Bluff, IL         USA        Olivia
# 300  2016    Student                Iowa City, IA         USA           Sam
# 301  2016    Student                     Mesa, AZ         USA       Melanie
# 302  2016    Student                Princeton, NJ         USA       Allison
# 303  2016    Student              Eagle River, AK         USA          Anna
# 304  2016    Student                Iowa City, IA         USA          Maya
# 305  2016    Student              New Orleans, LA         USA         Grace
# 306  2016  Chaperone                 Gizah, Cairo       Egypt        Aamena
# 307  2016  Chaperone                       Beirut     Lebanon        Serine
# 308  2016  Chaperone                       Moscow      Russia       Tatiana
# 309  2016  Chaperone                    New Delhi       India       Kandala
# 310  2016  Chaperone                      Bishkek  Kyrgyzstan        Zhamby
# 311  2016    Faculty                      Colombo   Sri Lanka        Ameena
# 312  2016    Faculty                  Lincoln, NE         USA          Mary
# 313  2016    Faculty  Vancouver, British Colombia      Canada         Karim
# 314  2016    Faculty                       Moscow      Russia         Alisa
# 315  2016    Faculty                Baltimore, MD         USA          Dora
#
#             last_name       lat       long
# 266             Gaeva  59.21667   39.90000
# 267           Galkina  55.75000   37.61667
# 268       Karnaukhova  54.70028   20.45306
# 269          Komarova  51.83333  107.60000
# 270         Kuznetsov  55.75000   37.61667
# 271       Martirosian  55.75000   37.61667
# 272       Shestopalov  55.75000   37.61667
# 273         Zhigalova  51.53333   46.01667
# 274              Ball  40.75000 -111.88333
# 275           Caldera  38.98472  -77.11306
# 276           Chitnis  33.66944 -117.82306
# 277            Clarke  33.55500 -116.67361
# 278          Gannholm  47.60972 -122.33306
# 279           Huggins  39.61583 -104.91139
# 280         McCormick  32.22167 -110.92639
# 281             Marer  33.86639 -118.39972
# 282           Matsuda  20.02028 -155.66778
# 283       Powell-Palm  45.67778 -111.04722
# 284           Sickles  40.74881  -74.26151
# 285           Walters  41.83694  -87.68472
# 286             Irfan  23.70000   90.36667
# 287           Mohamed   6.93444   79.84278
# 288    Mohamed Zarook   6.93444   79.84278
# 289           Ibrahim  31.54972   74.34361
# 290             Pasha  31.00000   72.00000
# 291            Saleem  24.86000   67.01000
# 292            Subedi  24.86000   67.01000
# 293            Pandey  24.86000   67.01000
# 294  Lachungpa Bhutia  27.31667   88.60000
# 295              Nair  18.97500   72.82583
# 296        Umurzakova  42.48333   78.40000
# 297         Omuraliev  42.87472   74.61222
# 298             Adler  40.75000 -111.88333
# 299             Alger  42.28333  -87.85000
# 300           Anthony  41.66010  -91.53420
# 301          Herrmann  33.41500 -111.83139
# 302             Huang  40.35712  -74.67017
# 303             Lance  61.32139 -149.56778
# 304  Meadows-Claussen  41.66010  -91.53420
# 305             Morse  29.95000  -90.06667
# 306             Zayed  30.05000   31.23333
# 307            Jaafar  33.88694   35.51306
# 308          Gurevich  55.75000   37.61667
# 309             Singh  28.61389   77.20889
# 310     Dzhusubalieva  42.87472   74.61222
# 311           Hussein   6.93444   79.84278
# 312           Hickman  40.81056  -90.68028
# 313            Alrawi  49.25000 -123.10000
# 314           Ganieva  55.75000   37.61667
# 315            Malech  39.28333  -76.61667

# %% [markdown]
# #### String Formatting
#
# Remove all of the quotes, paratheses, and nastiness from the dataset.

# %%
def clean_col(column, junk_str):
    """
    Removes an unwanted character from a Pandas DF column/series
    """
    column = column.str.replace(junk_str, '')
    return column

# %%
# For each column, and for each junk str, remove it!
for col in ['city', 'country', 'first_name', 'last_name']:
    for junk in ['"', "'", '?',r"\(.*\)"]:
        df[col] = clean_col(df[col], junk)

# %%
df.iloc[:200]
# Out:
#      year     status                                city    country  \
# 0    2008    Student                  Adonis Zouk Mosbeh    Lebanon
# 1    2008    Student                              Kuwait     Jordan
# 2    2008    Student                           Bazourieh    Lebanon
# 3    2008    Student                        Kufur Yassif     Israel
# 4    2008    Student                               Amman     Jordan
# 5    2008    Student                           Jerusalem     Israel
# 6    2008    Student                               Amman     Jordan
# 7    2008  Chaperone                                         Jordan
# 8    2008  Chaperone                                         Jordan
# 9    2008    Student                            Ramallah  Palestine
# 10   2008    Student                           Gaza City  Palestine
# 11   2008    Student                              Aleppo      Syria
# 12   2008    Student                              Aleppo      Syria
# 13   2008    Student                            Ramallah  Palestine
# 14   2008    Student                              Aleppo      Syria
# 15   2009    Student                           Jerusalem     Israel
# 16   2009    Student                             Darayya      Syria
# 17   2009    Student                             Darayya      Syria
# 18   2009  Chaperone                               Amman     Jordan
# 19   2009    Student                               Amman     Jordan
# 20   2009    Student                               Amman     Jordan
# 21   2009  Chaperone                             Darayya      Syria
# 22   2009    Student                              Beirut    Lebanon
# 23   2009    Student                            Tel Aviv     Israel
# 24   2009    Student                               Amman     Jordan
# 25   2009    Student                           Bethlehem  West Bank
# 26   2009    Student                           Jerusalem  West Bank
# 27   2009    Student                                Akko     Israel
# 28   2009  Chaperone                           Jerusalem     Israel
# 29   2009  Chaperone                                         Jordan
# ..    ...        ...                                 ...        ...
# 170  2014    Student                         Chicago, IL        USA
# 171  2014    Student                       San Diego, CA        USA
# 172  2014    Student                        Gibsonia, PA        USA
# 173  2014    Student  Buturlino, Nizhegordoskyire region     Russia
# 174  2014    Student                        Chandler, AZ        USA
# 175  2014  Chaperone                               Oujda    Morocco
# 176  2014    Student                          Marion, IA        USA
# 177  2014    Student                               Amman     Jordan
# 178  2014    Faculty                      Louisville, KY        USA
# 179  2014    Student                  Chamzinka Mordovia     Russia
# 180  2014    Student                              Manama    Bahrain
# 181  2014  Chaperone                               Kazan     Russia
# 182  2014    Student                        Oak Park, IL        USA
# 183  2014    Student                      Boca Raton, FL        USA
# 184  2014    Student                              Beirut    Lebanon
# 185  2014    Student                         Memphis, TN        USA
# 186  2014    Student                              Moscow     Russia
# 187  2014    Student                                Giza      Egypt
# 188  2014    Student                        Santa Fe, NM        USA
# 189  2015    Student         Baqa Al-Gharbia, Haifa Dis.     Israel
# 190  2015    Faculty                            Istanbul     Turkey
# 191  2015    Student                            Istanbul     Turkey
# 192  2015    Student                              Muscat       Oman
# 193  2015    Student                             Baghdad       Iraq
# 194  2015    Faculty                           Vancouver     Canada
# 195  2015    Student                             Yerevan    Armenia
# 196  2015  Chaperone                             Yerevan    Armenia
# 197  2015    Student                            Istanbul     Turkey
# 198  2015    Student                               Cairo      Egypt
# 199  2015    Student                       Gorno-Altaisk     Russia
#
#     first_name      last_name       lat       long
# 0       Eliane           Aoun  33.95500   35.61472
# 1         Hiba       as-Masri  29.36972   47.97833
# 2          Ali         Awarke  33.25389   35.27167
# 3        Randa       Ghantous  32.95472   35.16528
# 4        Karim          Ghawi  31.94972   35.93278
# 5         Ehab        Ghosheh  31.78333   35.21667
# 6        Faris          Jaber  31.94972   35.93278
# 7        Hiyam        Mahmoud  31.24000   36.51000
# 8        Reina           Mina  31.24000   36.51000
# 9         Qais          Mousa  31.90000   35.20000
# 10        Rand           Safi  31.51667   34.45000
# 11       Samar          Saleh  36.21667   37.16667
# 12       Jalal         Sirees  36.21667   37.16667
# 13        Lina         Soufan  31.90000   35.20000
# 14       Edwar          Tarzi  36.21667   37.16667
# 15        Bana          Aassy  31.78333   35.21667
# 16        Lora          Abaza  33.45000   36.25000
# 17        Yara    Abou Fakher  33.45000   36.25000
# 18        Asma      Abu-Dahab  31.94972   35.93278
# 19        Zaid      Al-Nassir  31.94972   35.93278
# 20      Bashar    Al-Sawaftah  31.94972   35.93278
# 21      Soumer     Daghastani  33.45000   36.25000
# 22       Nadia        El Malt  33.88694   35.51306
# 23       Ahmad          Ezery  32.06667   34.78333
# 24         Iya        Ghassib  31.94972   35.93278
# 25       Irene        Ghattas  31.70306   35.19556
# 26        Majd         Iwidat  31.78333   35.21667
# 27        Nael           Roby  32.92778   35.08167
# 28      Basima       Takrouri  31.78333   35.21667
# 29       Nadio        Tellawi  31.24000   36.51000
# ..         ...            ...       ...        ...
# 170     Johnny      Lorenzana  41.83694  -87.68472
# 171      Kerry            Luo  32.71500 -117.16250
# 172    Katrina       Manrique  40.63000  -79.96944
# 173      Anton        Meshkov  55.56528   44.90056
# 174    Ruohan            Miao  33.30000 -111.83333
# 175     Daoudi        Mimoune  34.68917   -1.91139
# 176    Griffin           Neal  42.03778  -91.75972
# 177      Yazan          Omari  31.94972   35.93278
# 178       Kiki      Petrosino  38.22533  -85.74167
# 179      Alena       Piksaeva  54.40000   45.78333
# 180       Dana          Radhi  26.21667   50.58333
# 181   Svetlana     Seniukhina  55.78333   49.11667
# 182     Oksana          Snell  41.88333  -87.80000
# 183     Matias  Sosa-Wheelock  26.36861  -80.10000
# 184      Megry   Tchangoulian  33.88694   35.51306
# 185       Jada         Thomas  35.11750  -89.97111
# 186      Alina      Vasilyeva  55.75000   37.61667
# 187      Merna          Wahba  30.01667   31.21667
# 188      Raina        Wellman  35.66722 -105.96444
# 189       Orwa       Abu Mukh  32.42033   35.04218
# 190      Nazmi           Agil  41.01361   28.95500
# 191      Melis          Akbas  41.01361   28.95500
# 192      Hajir     Al Zadjali  23.60000   58.58333
# 193    Hussein    Al-Mshttawi  33.33333   44.38333
# 194      Karim         Alrawi  49.25000 -123.10000
# 195     Lianna      Arakelyan  40.18333   44.51667
# 196     Arevik    Ashkharoyan  40.18333   44.51667
# 197        Nur             Ba  41.01361   28.95500
# 198       Reem           Badr  30.05000   31.23333
# 199      Shunu     Baydalakov  51.95000   85.96667
#
# [200 rows x 8 columns]

# %%
df.to_csv((data_dir + 'canonical/student_data.csv'), index=False)
