# %% [markdown]
# # Outreach Data
#
# This notebook is just looking at the raw data, downloading it and getting it in the right shape.
#
# #### Requirements
#
# *Note-to-self:* Here's a list of things to keep in mind when going through the data/analysis.
#
# - Gaza, Tel Aviv, Israel, and Palestine need segmentation. (To be done by Natasa)
# - Some projects/classifications will need links added.

# %%
# Project variables
data_dir = '../data/'

outreach_f = data_dir + 'BTL-outreach.json'

# %%
# Libraries
import pandas as pd
import json

# %matplotlib inline

# %% [markdown]
# #### Extract Outreach data from ArcGIS data.

# %%
# Read in the ArcGIS data
with open(outreach_f) as data_file:    
    data = json.load(data_file)

# %%
data.keys()
# Out:
# dict_keys(['operationalLayers', 'baseMap', 'spatialReference', 'authoringApp', 'authoringAppVersion', 'version'])

# %%
oper_layers = data['operationalLayers'][0]

# %%
print("Layer keys: {}".format(oper_layers.keys()))

oper_layers['featureCollection']['layers']
# Out:
# Layer keys: dict_keys(['layerType', 'id', 'title', 'featureCollection', 'visibility', 'opacity'])
# [{'featureSet': {'features': [{'attributes': {'Category': 'International Conference',
#       'Country': 'Greece',
#       'FID': 1,
#       'Year': 2006,
#       'link': 'https://iwp.uiowa.edu/programs/international-conferences/the-new-symposium/2006'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 2449028.4976999983,
#       'y': 4721671.4454}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Jordan ',
#       'FID': 2,
#       'Year': 2007,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2007-middle-east'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 4007501.269099999,
#       'y': 3632748.677199997}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Palestinian Territories',
#       'FID': 3,
#       'Year': 2007,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2007-middle-east'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3918811.9481999986,
#       'y': 3753019.8122000024}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Turkey',
#       'FID': 4,
#       'Year': 2007,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2007-middle-east'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3886335.657299999,
#       'y': 4730127.296499997}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'Greece',
#       'FID': 5,
#       'Year': 2007,
#       'link': 'https://iwp.uiowa.edu/programs/international-conferences/the-new-symposium/2007'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 2449028.4976999983,
#       'y': 4721671.4454}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Cyprus',
#       'FID': 6,
#       'Year': 2008,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2008-cyprus'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3673542.9970000014,
#       'y': 4163880.5341000035}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Oman',
#       'FID': 7,
#       'Year': 2008,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2008-middle-east'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 6345210.6767,
#       'y': 2391878.159499999}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Yemen',
#       'FID': 8,
#       'Year': 2008,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2008-middle-east'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 5287675.313499998,
#       'y': 1746891.3497000001}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'Greece',
#       'FID': 9,
#       'Year': 2008,
#       'link': 'https://iwp.uiowa.edu/programs/international-conferences/the-new-symposium/2008'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 2449028.4976999983,
#       'y': 4721671.4454}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Kenya',
#       'FID': 10,
#       'Year': 2009,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2009-kenya-tour'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 4230140.451099999,
#       'y': 111324.74210000038}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'China',
#       'FID': 11,
#       'Year': 2009,
#       'link': 'https://iwp.uiowa.edu/programs/life-of-discovery/2009'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 11688546.0361,
#       'y': 4163880.5341000035}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Tunisia',
#       'FID': 12,
#       'Year': 2009,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2009-Tunis-Morocco-Tour'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 1001875.3172999993,
#       'y': 4028801.9067}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'China',
#       'FID': 13,
#       'Year': 2010,
#       'link': 'https://iwp.uiowa.edu/programs/life-of-discovery/2010'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 11688546.0361,
#       'y': 4163880.5341000035}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'China',
#       'FID': 14,
#       'Year': 2011,
#       'link': 'https://iwp.uiowa.edu/programs/life-of-discovery/2011'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 11688546.0361,
#       'y': 4163880.5341000035}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Nepal',
#       'FID': 15,
#       'Year': 2011,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2011-nepal-pakistan-uae-afghanistan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 9350837.1294,
#       'y': 3248973.5637999997}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Pakistan',
#       'FID': 16,
#       'Year': 2011,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2011-nepal-pakistan-uae-afghanistan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 7792363.857099999,
#       'y': 3503549.2663000003}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'United Arab Emirates',
#       'FID': 17,
#       'Year': 2011,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2011-nepal-pakistan-uae-afghanistan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 6011252.404599998,
#       'y': 2753408.000599999}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Afghanistan',
#       'FID': 18,
#       'Year': 2011,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2011-nepal-pakistan-uae-afghanistan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 7347085.993999999,
#       'y': 3895303.725900002}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Uruguay',
#       'FID': 19,
#       'Year': 2011,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2011-uruguay-bolivia'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -6233891.0857,
#       'y': -3895303.725900002}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Bolivia',
#       'FID': 20,
#       'Year': 2011,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2011-uruguay-bolivia'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -7235766.403000001,
#       'y': -1920824.7267000005}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Kenya',
#       'FID': 21,
#       'Year': 2011,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2011-kenya-tour'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 4230140.451099999,
#       'y': 111324.74210000038}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'China',
#       'FID': 22,
#       'Year': 2012,
#       'link': 'https://iwp.uiowa.edu/programs/life-of-discovery/2012'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 11688546.0361,
#       'y': 4163880.5341000035}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Mozambique',
#       'FID': 23,
#       'Year': 2012,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2012-Mozambique-and-Zimbabwe-Tour'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3896181.678100001,
#       'y': -2066831.4079999998}},
#     {'attributes': {'Category': 'International Conference',
#       'Country': 'Turkey',
#       'FID': 24,
#       'Year': 2013,
#       'link': 'http://iwp.uiowa.edu/programs/international-conferences/the-same-gate'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3886335.657299999,
#       'y': 4730127.296499997}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Sudan',
#       'FID': 25,
#       'Year': 2013,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2013-Sudan-and-South-Sudan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3339584.2239999995,
#       'y': 1804722.3500000015}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'South Sudan',
#       'FID': 26,
#       'Year': 2013,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2013-Sudan-and-South-Sudan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3339584.2239999995,
#       'y': 837290.2274000011}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Uzbekistan',
#       'FID': 27,
#       'Year': 2013,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2013-Uzbekistan-and-Turkmenistan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 7107649.922200002,
#       'y': 5117270.217600003}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Turkmenistan',
#       'FID': 28,
#       'Year': 2013,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2013-Uzbekistan-and-Turkmenistan'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 6679168.948800001,
#       'y': 4865941.627499998}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Burma',
#       'FID': 29,
#       'Year': 2013,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2013-burma-tour'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 10909309.9008,
#       'y': 2511524.9114999995}},
#     {'attributes': {'Category': 'Silk Routes',
#       'Country': 'Maldives',
#       'FID': 30,
#       'Year': 2014,
#       'link': 'http://iwp.uiowa.edu/programs/silk-routes'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 8126322.630100001,
#       'y': 356407.2265999988}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Haiti',
#       'FID': 31,
#       'Year': 2014,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2014-Haiti'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -8061386.5777,
#       'y': 2154935.809799999}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Cuba',
#       'FID': 32,
#       'Year': 2014,
#       'link': 'http://iwp.uiowa.edu/programs/reading-abroad/2014-Cuba'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -8849899.2203,
#       'y': 2511524.9114999995}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'China',
#       'FID': 33,
#       'Year': 2014,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2014-China'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 11688546.0361,
#       'y': 4163880.5341000035}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'United Arab Emirates',
#       'FID': 34,
#       'Year': 2014,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2014-United-Arab-Emirates'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 6011252.404599998,
#       'y': 2753408.000599999}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Turkey',
#       'FID': 35,
#       'Year': 2014,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2014-Armenia-Turkey'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3886335.657299999,
#       'y': 4730127.296499997}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Armenia',
#       'FID': 36,
#       'Year': 2014,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2014-Armenia-Turkey'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 5009376.5863999985,
#       'y': 4865941.627499998}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Venezuela',
#       'FID': 37,
#       'Year': 2015,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2015-Venezuela'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -7347085.994000001,
#       'y': 893463.5489999987}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Colombia',
#       'FID': 38,
#       'Year': 2015,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2015-Colombia'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -8015003.039100001,
#       'y': 445640.00939999893}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Ukraine',
#       'FID': 39,
#       'Year': 2015,
#       'link': 'https://iwp.uiowa.edu/programs/reading-abroad/2015-Ukraine'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 3562223.4059999995,
#       'y': 6274861.243900001}},
#     {'attributes': {'Category': 'Distance Learning',
#       'Country': 'Jordan ',
#       'FID': 40,
#       'Year': 2015,
#       'link': 'https://iwp.uiowa.edu/iwp-courses/distance-learning-courses/spring-2015/room-of-ones-own'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 4007501.269099999,
#       'y': 3632748.677199997}},
#     {'attributes': {'Category': 'Distance Learning',
#       'Country': 'Bahrain',
#       'FID': 41,
#       'Year': 2015,
#       'link': 'https://iwp.uiowa.edu/iwp-courses/distance-learning-courses/spring-2015/room-of-ones-own'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 5621634.0865,
#       'y': 2999080.4987000003}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Jordan ',
#       'FID': 42,
#       'Year': 2016,
#       'link': 'No info'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 4007501.269099999,
#       'y': 3632748.677199997}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'South Africa',
#       'FID': 43,
#       'Year': 2016,
#       'link': 'No info'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 2671667.6796999983,
#       'y': -3375645.921500001}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'India',
#       'FID': 44,
#       'Year': 2016,
#       'link': 'No info'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': 8571600.4932,
#       'y': 2273030.394699998}},
#     {'attributes': {'Category': 'Reading tour',
#       'Country': 'Ecuador',
#       'FID': 45,
#       'Year': 2016,
#       'link': 'No info'},
#      'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#       'x': -8627260.0383,
#       'y': -222683.90790000185}}],
#    'geometryType': 'esriGeometryPoint'},
#   'layerDefinition': {'advancedQueryCapabilities': {'supportsAdvancedQueryRelated': True,
#     'supportsDistinct': True,
#     'supportsOrderBy': True,
#     'supportsPagination': True,
#     'supportsQueryRelatedPagination': True,
#     'supportsQueryWithDistance': True,
#     'supportsQueryWithResultType': True,
#     'supportsReturningGeometryCentroid': False,
#     'supportsReturningQueryExtent': True,
#     'supportsSqlExpression': True,
#     'supportsStatistics': True},
#    'allowGeometryUpdates': True,
#    'capabilities': 'Query,Editing',
#    'copyrightText': '',
#    'currentVersion': 10.41,
#    'defaultVisibility': True,
#    'description': '',
#    'displayField': '',
#    'drawingInfo': {'renderer': {'field1': 'Category',
#      'type': 'uniqueValue',
#      'uniqueValueInfos': [{'label': 'Reading tour',
#        'symbol': {'angle': 0,
#         'color': [253, 127, 111, 255],
#         'outline': {'color': [26, 26, 26, 255],
#          'style': 'esriSLSSolid',
#          'type': 'esriSLS',
#          'width': 0.75},
#         'size': 6,
#         'style': 'esriSMSCircle',
#         'type': 'esriSMS',
#         'xoffset': 0,
#         'yoffset': 0},
#        'value': 'Reading tour'},
#       {'label': 'International Conference',
#        'symbol': {'angle': 0,
#         'color': [126, 176, 213, 255],
#         'outline': {'color': [26, 26, 26, 255],
#          'style': 'esriSLSSolid',
#          'type': 'esriSLS',
#          'width': 0.75},
#         'size': 6,
#         'style': 'esriSMSCircle',
#         'type': 'esriSMS',
#         'xoffset': 0,
#         'yoffset': 0},
#        'value': 'International Conference'},
#       {'label': 'Distance Learning',
#        'symbol': {'angle': 0,
#         'color': [178, 224, 97, 255],
#         'outline': {'color': [26, 26, 26, 255],
#          'style': 'esriSLSSolid',
#          'type': 'esriSLS',
#          'width': 0.75},
#         'size': 6,
#         'style': 'esriSMSCircle',
#         'type': 'esriSMS',
#         'xoffset': 0,
#         'yoffset': 0},
#        'value': 'Distance Learning'},
#       {'label': 'Silk Routes',
#        'symbol': {'angle': 0,
#         'color': [189, 126, 190, 255],
#         'outline': {'color': [26, 26, 26, 255],
#          'style': 'esriSLSSolid',
#          'type': 'esriSLS',
#          'width': 0.75},
#         'size': 6,
#         'style': 'esriSMSCircle',
#         'type': 'esriSMS',
#         'xoffset': 0,
#         'yoffset': 0},
#        'value': 'Silk Routes'}]}},
#    'extent': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#     'xmax': 11688546.0362,
#     'xmin': -8849899.2204,
#     'ymax': 6274861.244000001,
#     'ymin': -3895303.7260000017},
#    'fields': [{'alias': 'Category',
#      'defaultValue': None,
#      'domain': None,
#      'editable': True,
#      'length': 256,
#      'name': 'Category',
#      'nullable': True,
#      'sqlType': 'sqlTypeNVarchar',
#      'type': 'esriFieldTypeString'},
#     {'alias': 'Country',
#      'defaultValue': None,
#      'domain': None,
#      'editable': True,
#      'length': 256,
#      'name': 'Country',
#      'nullable': True,
#      'sqlType': 'sqlTypeNVarchar',
#      'type': 'esriFieldTypeString'},
#     {'alias': 'Year',
#      'defaultValue': None,
#      'domain': None,
#      'editable': True,
#      'name': 'Year',
#      'nullable': True,
#      'sqlType': 'sqlTypeInteger',
#      'type': 'esriFieldTypeInteger'},
#     {'alias': 'link',
#      'defaultValue': None,
#      'domain': None,
#      'editable': True,
#      'length': 256,
#      'name': 'link',
#      'nullable': True,
#      'sqlType': 'sqlTypeNVarchar',
#      'type': 'esriFieldTypeString'},
#     {'alias': 'FID',
#      'defaultValue': None,
#      'domain': None,
#      'editable': False,
#      'name': 'FID',
#      'nullable': False,
#      'sqlType': 'sqlTypeInteger',
#      'type': 'esriFieldTypeInteger'}],
#    'geometryType': 'esriGeometryPoint',
#    'globalIdField': '',
#    'hasAttachments': False,
#    'hasM': False,
#    'hasStaticData': False,
#    'hasZ': False,
#    'htmlPopupType': 'esriServerHTMLPopupTypeNone',
#    'id': 0,
#    'indexes': [],
#    'isDataVersioned': False,
#    'maxRecordCount': -1,
#    'maxRecordCountFactor': 1,
#    'name': 'Copy of IWP map',
#    'objectIdField': 'FID',
#    'relationships': [],
#    'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#    'standardMaxRecordCount': 32000,
#    'supportedQueryFormats': 'JSON, geoJSON',
#    'supportsAdvancedQueries': True,
#    'supportsApplyEditsWithGlobalIds': False,
#    'supportsAttachmentsByUploadId': True,
#    'supportsCalculate': True,
#    'supportsCoordinatesQuantization': True,
#    'supportsRollbackOnFailureParameter': True,
#    'supportsStatistics': True,
#    'supportsTruncate': False,
#    'supportsValidateSql': True,
#    'templates': [],
#    'tileMaxRecordCount': 8000,
#    'type': 'Feature Layer',
#    'typeIdField': '',
#    'types': [],
#    'useStandardizedQueries': False},
#   'nextObjectId': 46,
#   'popupInfo': {'description': None,
#    'fieldInfos': [{'fieldName': 'Category',
#      'format': None,
#      'isEditable': True,
#      'label': 'Category',
#      'stringFieldOption': 'textbox',
#      'tooltip': '',
#      'visible': True},
#     {'fieldName': 'Country',
#      'format': None,
#      'isEditable': True,
#      'label': 'Country',
#      'stringFieldOption': 'textbox',
#      'tooltip': '',
#      'visible': True},
#     {'fieldName': 'Year',
#      'format': {'digitSeparator': True, 'places': 0},
#      'isEditable': True,
#      'label': 'Year',
#      'stringFieldOption': 'textbox',
#      'tooltip': '',
#      'visible': True},
#     {'fieldName': 'link',
#      'format': None,
#      'isEditable': True,
#      'label': 'link',
#      'stringFieldOption': 'textbox',
#      'tooltip': '',
#      'visible': True},
#     {'fieldName': 'FID',
#      'format': {'digitSeparator': True, 'places': 0},
#      'isEditable': False,
#      'label': 'FID',
#      'stringFieldOption': 'textbox',
#      'tooltip': '',
#      'visible': True}],
#    'mediaInfos': [],
#    'showAttachments': False,
#    'title': ''}}]

# %%
layers = oper_layers['featureCollection']['layers']
len(layers)
# Out:
# 1

# %%
features = layers[0]['featureSet']['features']

print ("{} many features included.".format(len(features)))
# Out:
# 45 many features included.

# %%
features[0]
# Out:
# {'attributes': {'Category': 'International Conference',
#   'Country': 'Greece',
#   'FID': 1,
#   'Year': 2006,
#   'link': 'https://iwp.uiowa.edu/programs/international-conferences/the-new-symposium/2006'},
#  'geometry': {'spatialReference': {'latestWkid': 3857, 'wkid': 102100},
#   'x': 2449028.4976999983,
#   'y': 4721671.4454}}

# %%
filt_features = [x['attributes'] for x in features]
df = pd.DataFrame(filt_features)

df.drop('FID', axis=1, inplace=True)
df.head()
# Out:
#                    Category                  Country  Year  \
# 0  International Conference                   Greece  2006
# 1              Reading tour                  Jordan   2007
# 2              Reading tour  Palestinian Territories  2007
# 3              Reading tour                   Turkey  2007
# 4  International Conference                   Greece  2007
#
#                                                 link
# 0  https://iwp.uiowa.edu/programs/international-c...
# 1  https://iwp.uiowa.edu/programs/reading-abroad/...
# 2  https://iwp.uiowa.edu/programs/reading-abroad/...
# 3  https://iwp.uiowa.edu/programs/reading-abroad/...
# 4  https://iwp.uiowa.edu/programs/international-c...

# %% [markdown]
# #### Rename Countries to match participant naming.

# %%
df.Country.unique().tolist()
# Out:
# ['Greece',
#  'Jordan ',
#  'Palestinian Territories',
#  'Turkey',
#  'Cyprus',
#  'Oman',
#  'Yemen',
#  'Kenya',
#  'China',
#  'Tunisia',
#  'Nepal',
#  'Pakistan',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Uruguay',
#  'Bolivia',
#  'Mozambique',
#  'Sudan',
#  'South Sudan',
#  'Uzbekistan',
#  'Turkmenistan',
#  'Burma',
#  'Maldives',
#  'Haiti',
#  'Cuba',
#  'Armenia',
#  'Venezuela',
#  'Colombia',
#  'Ukraine',
#  'Bahrain',
#  'South Africa',
#  'India',
#  'Ecuador']

# %%
country_aliases = {
    'USA': 'United States of America',
    'U.S.': 'United States of America',
    'US': 'United States of America',
    'Kuwait (but she is Lebanese)': 'Kuwait',
    'Syria ': 'Syria',
    'Palestinian Territories': 'Palestine',
    'Palestinian Territories ': 'Palestine',
    'Jordan ': 'Jordan',
    'Burma': 'Myanmar'
}

df['Country'] = df['Country'].map(lambda x: country_aliases[x] if x in country_aliases else x)

# %%
df.Country.tolist()
# Out:
# ['Greece',
#  'Jordan',
#  'Palestine',
#  'Turkey',
#  'Greece',
#  'Cyprus',
#  'Oman',
#  'Yemen',
#  'Greece',
#  'Kenya',
#  'China',
#  'Tunisia',
#  'China',
#  'China',
#  'Nepal',
#  'Pakistan',
#  'United Arab Emirates',
#  'Afghanistan',
#  'Uruguay',
#  'Bolivia',
#  'Kenya',
#  'China',
#  'Mozambique',
#  'Turkey',
#  'Sudan',
#  'South Sudan',
#  'Uzbekistan',
#  'Turkmenistan',
#  'Myanmar',
#  'Maldives',
#  'Haiti',
#  'Cuba',
#  'China',
#  'United Arab Emirates',
#  'Turkey',
#  'Armenia',
#  'Venezuela',
#  'Colombia',
#  'Ukraine',
#  'Jordan',
#  'Bahrain',
#  'Jordan',
#  'South Africa',
#  'India',
#  'Ecuador']

# %%
df.head(2)
# Out:
#                    category country  year  \
# 0  International Conference  Greece  2006
# 1              Reading tour  Jordan  2007
#
#                                                 link
# 0  https://iwp.uiowa.edu/programs/international-c...
# 1  https://iwp.uiowa.edu/programs/reading-abroad/...

# %% [markdown]
# #### Rename Columns
#
# Something human readable, prefferably.

# %%
new_cols = ['category', 'country', 'year', 'link']
df.columns = new_cols

df.head(2)
# Out:
#                    category country  year  \
# 0  International Conference  Greece  2006
# 1              Reading tour  Jordan  2007
#
#                                                 link
# 0  https://iwp.uiowa.edu/programs/international-c...
# 1  https://iwp.uiowa.edu/programs/reading-abroad/...

# %% [markdown]
# ---

# %%
outreach_canon_f = '../data/canonical/outreach-programs.csv'
df.to_csv(outreach_canon_f, index=False)
